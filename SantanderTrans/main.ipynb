# %%
import kagglemethods.preprocessing as pp
import pandas as pd
import os
import kagglemethods

# %%
train_df = pd.read_csv('./input/train.csv')

# %%
pd.set_option('max_columns',1000) 
pd.set_option('max_row',300)

# %%
pp.missing_data(train_df)
# Out:
#         ID_code target    var_0    var_1    var_2    var_3    var_4    var_5  \
# Total         0      0        0        0        0        0        0        0
# Percent       0      0        0        0        0        0        0        0
# Types    object  int64  float64  float64  float64  float64  float64  float64
#
#            var_6    var_7    var_8    var_9   var_10   var_11   var_12  \
# Total          0        0        0        0        0        0        0
# Percent        0        0        0        0        0        0        0
# Types    float64  float64  float64  float64  float64  float64  float64
#
#           var_13   var_14   var_15   var_16   var_17   var_18   var_19  \
# Total          0        0        0        0        0        0        0
# Percent        0        0        0        0        0        0        0
# Types    float64  float64  float64  float64  float64  float64  float64
#
#           var_20   var_21   var_22   var_23   var_24   var_25   var_26  \
# ...

# %%
pp.univariate_dist(train_df,'target',variable_type='cate')

# %%
kagglemethods??

# %%
import kagglemethods.xgboost_classification as xcv

# %%
xcv??

# %%
train_df.shape
# Out:
# (200000, 202)
