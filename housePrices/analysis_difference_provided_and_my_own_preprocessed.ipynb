# %%
#不知道为什么我预处理的数据会有这么严重的过拟合，所以这个notbook是用来分析比较两个数据的
import numpy as np
import pandas as pd

my_train = pd.read_csv('./input/processed_train_logged.csv')
my_test =  pd.read_csv('./input/processed_test_logged.csv')
pro_train = pd.read_csv('./input/provided_train.csv')
pro_test = pd.read_csv('./input/provided_test.csv')

# %%
my_train.head()
# Out:
#    Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1    0.067320    -0.197232 -0.217841     0.646073    -0.507197   1.046078
# 1   2   -0.873466     0.478622 -0.072032    -0.063174     2.187904   0.154737
# 2   3    0.067320    -0.062061  0.137173     0.646073    -0.507197   0.980053
# 3   4    0.302516    -0.422517 -0.078371     0.646073    -0.507197  -1.859033
# 4   5    0.067320     0.658850  0.518814     1.355319    -0.507197   0.947040
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1    ...      SaleType_WD  SaleType_nan  \
# 0      0.896679    0.523738    0.580708    ...                1             0
# 1     -0.395536   -0.570703    1.177709    ...                1             0
# 2      0.848819    0.333886    0.097840    ...                1             0
# 3     -0.682695   -0.570703   -0.494771    ...                1             0
# 4      0.753100    1.383655    0.468770    ...                1             0
#
# ...

# %%
pro_train.head()
# Out:
#          Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# 0 -1.731161    0.067320    -0.184443 -0.217841     0.646073    -0.507197
# 1 -1.729974   -0.873466     0.458096 -0.072032    -0.063174     2.187904
# 2 -1.728788    0.067320    -0.055935  0.137173     0.646073    -0.507197
# 3 -1.727601    0.302516    -0.398622 -0.078371     0.646073    -0.507197
# 4 -1.726415    0.067320     0.629439  0.518814     1.355319    -0.507197
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1   ...    SaleType_WD  \
# 0   1.046078      0.896679    0.523038    0.580708   ...              1
# 1   0.154737     -0.395536   -0.569893    1.177709   ...              1
# 2   0.980053      0.848819    0.333448    0.097840   ...              1
# 3  -1.859033     -0.682695   -0.569893   -0.494771   ...              1
# 4   0.947040      0.753100    1.381770    0.468770   ...              1
#
#    SaleType_nan  SaleCondition_Abnorml  SaleCondition_AdjLand  \
# ...
